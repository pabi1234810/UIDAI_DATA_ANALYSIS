# %% [markdown]
# <a href="https://colab.research.google.com/github/pabi1234810/UIDAI_DATA_ANALYSIS/blob/main/UIDAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries and data cleaning and checking the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_demo1 = pd.read_csv("/content/api_data_aadhar_demographic_0_500000.csv")
df_demo1.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df_demo2 = pd.read_csv("/content/api_data_aadhar_demographic_500000_1000000.csv")
df_demo2.head()
# Out:
#          date        state    district  pincode  demo_age_5_17  demo_age_17_
# 0  19-09-2025  Maharashtra      Satara   415517              0             2
# 1  19-09-2025  Maharashtra      Satara   415518              0             2
# 2  19-09-2025  Maharashtra      Satara   415520              0             3
# 3  19-09-2025  Maharashtra      Satara   415539              1             5
# 4  19-09-2025  Maharashtra  Sindhudurg   416510              4            37

# %%
df_demo3 = pd.read_csv("/content/api_data_aadhar_demographic_1000000_1500000.csv")
df_demo3.head()
# Out:
#          date       state    district  pincode  demo_age_5_17  demo_age_17_
# 0  01-11-2025  Puducherry    Karaikal   609603              0             4
# 1  01-11-2025  Puducherry    Karaikal   609605              0             3
# 2  01-11-2025  Puducherry    Karaikal   609606              0             5
# 3  01-11-2025  Puducherry  Puducherry   605011              2             6
# 4  01-11-2025  Puducherry  Puducherry   605111              0             1

# %%
df_demo4 = pd.read_csv("/content/api_data_aadhar_demographic_1500000_2000000.csv")
df_demo4.head()
# Out:
#          date      state district  pincode  demo_age_5_17  demo_age_17_
# 0  18-11-2025  Karnataka    Hasan   573118              0             2
# 1  18-11-2025  Karnataka    Hasan   573124              1             3
# 2  18-11-2025  Karnataka    Hasan   573150              0             2
# 3  18-11-2025  Karnataka   Hassan   573113              0             1
# 4  18-11-2025  Karnataka   Hassan   573120              1             4

# %%
df_demo5 = pd.read_csv("/content/api_data_aadhar_demographic_2000000_2071700.csv")
df_demo5.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_
# 0  16-12-2025  Madhya Pradesh  Shajapur   465113              0             4
# 1  16-12-2025  Madhya Pradesh  Shajapur   465226              2            14
# 2  16-12-2025  Madhya Pradesh  Shajapur   465339              1             2
# 3  16-12-2025  Madhya Pradesh  Shajapur   465447              1            19
# 4  16-12-2025  Madhya Pradesh   Sheopur   476332             11            25

# %%
print("All available 'api_data_aadhar_demographic_*.csv' files have been loaded (df_demo1 to df_demo5).")
print("Files for df_demo6 and beyond (e.g., /content/api_data_aadhar_demographic_2500000_3000000.csv) were not found in the file system.")
# Out:
# All available 'api_data_aadhar_demographic_*.csv' files have been loaded (df_demo1 to df_demo5).
# Files for df_demo6 and beyond (e.g., /content/api_data_aadhar_demographic_2500000_3000000.csv) were not found in the file system.

# %% [markdown]
# ## Load Enrollment Datasets

# %%
df_enrol1 = pd.read_csv("/content/api_data_aadhar_enrolment_0_500000.csv")
df_enrol1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df_enrol2 = pd.read_csv("/content/api_data_aadhar_enrolment_500000_1000000.csv")
df_enrol2.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df_enrol3 = pd.read_csv("/content/api_data_aadhar_enrolment_1000000_1006029.csv")
df_enrol3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
df_enrolment.isnull().sum()
# Out:
# date                0
# state               0
# district            0
# pincode             0
# age_0_5             0
# age_5_17            0
# age_18_greater      0
# enrollment_year     0
# enrollment_month    0
# dtype: int64

# %%
df_enrolment = pd.concat([df_enrol1, df_enrol2, df_enrol3], ignore_index=True)
df_enrolment.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df_enrolment.shape
# Out:
# (1006029, 7)

# %%
df_enrolment.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df_enrolment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006029 entries, 0 to 1006028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date            1006029 non-null  object
#  1   state           1006029 non-null  object
#  2   district        1006029 non-null  object
#  3   pincode         1006029 non-null  int64
#  4   age_0_5         1006029 non-null  int64
#  5   age_5_17        1006029 non-null  int64
#  6   age_18_greater  1006029 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 53.7+ MB

# %%
df_enrolment.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# dtype: int64

# %%
df_enrolment.describe()
# Out:
#             pincode       age_0_5      age_5_17  age_18_greater
# count  1.006029e+06  1.006029e+06  1.006029e+06    1.006029e+06
# mean   5.186415e+05  3.525709e+00  1.710074e+00    1.673441e-01
# std    2.056360e+05  1.753851e+01  1.436963e+01    3.220525e+00
# min    1.000000e+05  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    3.636410e+05  1.000000e+00  0.000000e+00    0.000000e+00
# 50%    5.174170e+05  2.000000e+00  0.000000e+00    0.000000e+00
# 75%    7.001040e+05  3.000000e+00  1.000000e+00    0.000000e+00
# max    8.554560e+05  2.688000e+03  1.812000e+03    8.550000e+02

# %% [markdown]
# ## Loading Demographic Dataset

# %%
df_demographic = pd.concat([df_demo1, df_demo2, df_demo3, df_demo4, df_demo5], ignore_index=True)
df_demographic.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df_demographic.shape
# Out:
# (2071700, 6)

# %%
df_demographic.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071700 entries, 0 to 2071699
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           object
#  1   state          object
#  2   district       object
#  3   pincode        int64
#  4   demo_age_5_17  int64
#  5   demo_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.8+ MB

# %%
df_demographic.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
df_demographic.describe()
# Out:
#             pincode  demo_age_5_17  demo_age_17_
# count  2.071700e+06   2.071700e+06  2.071700e+06
# mean   5.278318e+05   2.347552e+00  2.144701e+01
# std    1.972933e+05   1.490355e+01  1.252498e+02
# min    1.000000e+05   0.000000e+00  0.000000e+00
# 25%    3.964690e+05   0.000000e+00  2.000000e+00
# 50%    5.243220e+05   1.000000e+00  6.000000e+00
# 75%    6.955070e+05   2.000000e+00  1.500000e+01
# max    8.554560e+05   2.690000e+03  1.616600e+04

# %%
state_updates = df_demographic.groupby('state')[['demo_age_5_17', 'demo_age_17_']].sum()
state_updates['total_updates'] = state_updates['demo_age_5_17'] + state_updates['demo_age_17_']

print("\nTop 5 states with most demographic updates:")
print(state_updates.sort_values(by='total_updates', ascending=False).head(5))

print("\nBottom 5 states with fewest demographic updates:")
print(state_updates.sort_values(by='total_updates', ascending=True).head(5))
# Out:
# Top 5 states with most demographic updates:
#                 demo_age_5_17  demo_age_17_  total_updates
# state
# Uttar Pradesh          790308       7752020        8542328
# Maharashtra            273322       4781280        5054602
# Bihar                  380023       4434327        4814350
# West Bengal            242549       3629623        3872172
# Madhya Pradesh         407098       2505840        2912938
#
# Bottom 5 states with fewest demographic updates:
#                       demo_age_5_17  demo_age_17_  total_updates
# state
# Raja Annamalai Puram              0             1              1
# Puttenahalli                      0             1              1
# Nagpur                            0             1              1
# 100000                            0             2              2
# Madanapalle                       0             2              2

# %%
df_demographic['date'] = pd.to_datetime(df_demographic['date'], format='%d-%m-%Y')
df_demographic['update_year'] = df_demographic['date'].dt.year
df_demographic['update_month'] = df_demographic['date'].dt.month

trends_over_time = df_demographic.groupby(['update_year', 'update_month'])[['demo_age_5_17', 'demo_age_17_']].sum().reset_index()
trends_over_time['date'] = pd.to_datetime(trends_over_time['update_year'].astype(str) + '-' + trends_over_time['update_month'].astype(str) + '-01')

plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='demo_age_5_17', data=trends_over_time, label='Age 5-17 Updates', marker='o')
sns.lineplot(x='date', y='demo_age_17_', data=trends_over_time, label='Age 17+ Updates', marker='o')
plt.title('Demographic Update Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Updates')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_demographic['date'] = pd.to_datetime(df_demographic['date'], format='%d-%m-%Y')
df_demographic['update_year'] = df_demographic['date'].dt.year
df_demographic['update_month'] = df_demographic['date'].dt.month

trends_over_time = df_demographic.groupby(['update_year', 'update_month'])[['demo_age_5_17', 'demo_age_17_']].sum().reset_index()
print("Demographic update trends over time:")
print(trends_over_time)
# Out:
# Demographic update trends over time:
#    update_year  update_month  demo_age_5_17  demo_age_17_
# 0         2025             3         976095      10171463
# 1         2025             4         198744       1316928
# 2         2025             5         204893       1361394
# 3         2025             6         197767       1487795
# 4         2025             7         288449       1932266
# 5         2025             9         770788       6553272
# 6         2025            10         479232       4531734
# 7         2025            11         821273       8566328
# 8         2025            12         926183       8510583

# %%
df_enrolment['date'] = pd.to_datetime(df_enrolment['date'], format='%d-%m-%Y')
df_enrolment['enrollment_year'] = df_enrolment['date'].dt.year
df_enrolment['enrollment_month'] = df_enrolment['date'].dt.month

enrollment_trends_over_time = df_enrolment.groupby(['enrollment_year', 'enrollment_month'])[['age_0_5', 'age_5_17', 'age_18_greater']].sum().reset_index()
print("Enrollment trends over time:")
print(enrollment_trends_over_time)
# Out:
# Enrollment trends over time:
#    enrollment_year  enrollment_month  age_0_5  age_5_17  age_18_greater
# 0             2025                 3     5367      7407            3808
# 1             2025                 4   141154     91371           24913
# 2             2025                 5    95342     71690           16584
# 3             2025                 6    98943     99911           16880
# 4             2025                 7   318352    263333           35183
# 5             2025                 9   995612    465401           14866
# 6             2025                10   562856    238958           16106
# 7             2025                11   769156    297658           25193
# 8             2025                12   560183    184655           14820

# %%
enrollment_trends_over_time['date'] = pd.to_datetime(enrollment_trends_over_time['enrollment_year'].astype(str) + '-' + enrollment_trends_over_time['enrollment_month'].astype(str) + '-01')

plt.figure(figsize=(14, 7))
sns.lineplot(x='date', y='age_0_5', data=enrollment_trends_over_time, label='Age 0-5 Enrollments', marker='o')
sns.lineplot(x='date', y='age_5_17', data=enrollment_trends_over_time, label='Age 5-17 Enrollments', marker='o')
sns.lineplot(x='date', y='age_18_greater', data=enrollment_trends_over_time, label='Age 18+ Enrollments', marker='o')
plt.title('Enrollment Trends Over Time by Age Group')
plt.xlabel('Date')
plt.ylabel('Number of Enrollments')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
update_counts = pd.DataFrame({
    'Age Group': ['5-17', '17+'],
    'Total Updates': [total_demo_age_5_17_updates, total_demo_age_17_plus_updates]
})

plt.figure(figsize=(8, 6))
sns.barplot(x='Age Group', y='Total Updates', data=update_counts, palette='viridis')
plt.title('Total Demographic Updates by Age Group')
plt.ylabel('Total Number of Updates')
plt.xlabel('Age Group')
plt.show()

# %% [markdown]
# #Combining Demographic and Enrolment

# %%
df_combined = pd.merge(df_demographic, df_enrolment, on=['date', 'state', 'district', 'pincode'], how='inner')
df_combined.head()
# Out:
#         date      state     district  pincode  demo_age_5_17  demo_age_17_  \
# 0 2025-04-01  Rajasthan        Ajmer   305001            407          2851
# 1 2025-04-01  Karnataka    Bengaluru   560067            138           766
# 2 2025-04-01    Haryana      Gurgaon   122001            867          5452
# 3 2025-04-01      Delhi  South Delhi   110074            301          1805
# 4 2025-04-01  Rajasthan      Jodhpur   342001            300          2923
#
#    update_year  update_month  age_0_5  age_5_17  age_18_greater  \
# 0         2025             4      522       121              22
# 1         2025             4      158        26              39
# 2         2025             4      426       145              22
# 3         2025             4      253       102              10
# 4         2025             4      770       191              31
#
#    enrollment_year  enrollment_month
# 0             2025                 4
# 1             2025                 4
# ...

# %%
correlation_5_17 = df_combined['demo_age_5_17'].corr(df_combined['age_5_17'])
correlation_17_plus = df_combined['demo_age_17_'].corr(df_combined['age_18_greater'])

print(f"Correlation between demographic updates (age 5-17) and enrollments (age 5-17): {correlation_5_17:.2f}")
print(f"Correlation between demographic updates (age 17+) and enrollments (age 18+): {correlation_17_plus:.2f}")
# Out:
# Correlation between demographic updates (age 5-17) and enrollments (age 5-17): 0.80
# Correlation between demographic updates (age 17+) and enrollments (age 18+): 0.47

# %%
plt.figure(figsize=(14, 7))
# Ensure state_updates and top_10_states are available. They are from previous execution.
# If this cell were to be run independently, these would need to be re-calculated.
top_10_states = state_updates.sort_values(by='total_updates', ascending=False).head(10)
sns.barplot(x=top_10_states.index, y='total_updates', data=top_10_states, palette='crest')
plt.title('Top 10 States with Most Demographic Updates (with numbers)')
plt.xlabel('State')
plt.ylabel('Total Number of Updates')
plt.xticks(rotation=45, ha='right')

# Add numerical labels on top of the bars
for index, row in top_10_states.iterrows():
    plt.text(index, row['total_updates'], f'{row['total_updates']:,}', color='black', ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.scatterplot(x='demo_age_5_17', y='age_5_17', data=df_combined)
plt.title('Demographic Updates vs. Enrollments (Age 5-17)')
plt.xlabel('Demographic Updates (Age 5-17)')
plt.ylabel('Enrollments (Age 5-17)')

plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.scatterplot(x='demo_age_17_', y='age_18_greater', data=df_combined)
plt.title('Demographic Updates vs. Enrollments (Age 17+ and 18+)')
plt.xlabel('Demographic Updates (Age 17+)')
plt.ylabel('Enrollments (Age 18+)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Biometric Dataset

# %%
df_biometric = pd.concat([df1, df2, df3, df4], ignore_index=True)
df_biometric.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df_biometric['date'] = pd.to_datetime(df_biometric['date'], format='%d-%m-%Y')
df_biometric['biometric_year'] = df_biometric['date'].dt.year
df_biometric['biometric_month'] = df_biometric['date'].dt.month

biometric_trends_over_time = df_biometric.groupby(['biometric_year', 'biometric_month'])[['bio_age_5_17', 'bio_age_17_']].sum().reset_index()
biometric_trends_over_time['date'] = pd.to_datetime(biometric_trends_over_time['biometric_year'].astype(str) + '-' + biometric_trends_over_time['biometric_month'].astype(str) + '-01')

plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='bio_age_5_17', data=biometric_trends_over_time, label='Age 5-17 Biometric Updates', marker='o')
sns.lineplot(x='date', y='bio_age_17_', data=biometric_trends_over_time, label='Age 17+ Biometric Updates', marker='o')
plt.title('Biometric Update Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Biometric Updates')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_biometric_enrolment_combined.head()
# Out:
#         date      state         district  pincode  bio_age_5_17  bio_age_17_  \
# 0 2025-04-01      Bihar  Kaimur (Bhabua)   821106           860          680
# 1 2025-04-01      Assam          Nalbari   781337            50           14
# 2 2025-04-01      Bihar   West Champaran   845453           643          668
# 3 2025-04-01      Assam           Kamrup   781102           654          104
# 4 2025-04-01  Rajasthan            Churu   331403           598          735
#
#    biometric_year  biometric_month  age_0_5  age_5_17  age_18_greater  \
# 0            2025                4      146       199              12
# 1            2025                4       15        11              23
# 2            2025                4      271       300              20
# 3            2025                4      126        55              13
# 4            2025                4      316       141              12
#
#    enrollment_year  enrollment_month
# 0             2025                 4
# ...

# %%
biometric_updates_per_state = df_biometric.groupby('state')[['bio_age_5_17', 'bio_age_17_']].sum()
biometric_updates_per_state['total_biometric_updates'] = biometric_updates_per_state['bio_age_5_17'] + biometric_updates_per_state['bio_age_17_']
print("Biometric updates per state:")
print(biometric_updates_per_state.head())
# Out:
# Biometric updates per state:
#                              bio_age_5_17  bio_age_17_  \
# state
# Andaman & Nicobar Islands             405         1979
# Andaman and Nicobar Islands         11401         6913
# Andhra Pradesh                    2241448      1473144
# Arunachal Pradesh                   42894        29500
# Assam                              596624       386098
#
#                              total_biometric_updates
# state
# Andaman & Nicobar Islands                       2384
# Andaman and Nicobar Islands                    18314
# Andhra Pradesh                               3714592
# Arunachal Pradesh                              72394
# Assam                                         982722

# %%
top_10_biometric_states = biometric_updates_per_state.sort_values(by='total_biometric_updates', ascending=False).head(10)
print("Top 10 states with the most biometric updates:")
print(top_10_biometric_states)
# Out:
# Top 10 states with the most biometric updates:
#                 bio_age_5_17  bio_age_17_  total_biometric_updates
# state
# Uttar Pradesh        6207105      3370630                  9577735
# Maharashtra          3512712      5713427                  9226139
# Madhya Pradesh       3200117      2723654                  5923771
# Bihar                2208141      2689446                  4897587
# Tamil Nadu           2227252      2470865                  4698117
# Rajasthan            2066747      1928208                  3994955
# Andhra Pradesh       2241448      1473144                  3714592
# Gujarat              1460655      1735859                  3196514
# Chhattisgarh          884553      1764176                  2648729
# Karnataka            1244999      1390955                  2635954

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x=top_10_biometric_states.index, y='total_biometric_updates', data=top_10_biometric_states, palette='viridis')
plt.title('Top 10 States with Most Biometric Updates')
plt.xlabel('State')
plt.ylabel('Total Number of Biometric Updates')
plt.xticks(rotation=45, ha='right')

# Add numerical labels on top of the bars
for index, row in top_10_biometric_states.iterrows():
    plt.text(index, row['total_biometric_updates'], f'{row['total_biometric_updates']:,}', color='black', ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
df_biometric_enrolment_combined = pd.merge(df_biometric, df_enrolment, on=['date', 'state', 'district', 'pincode'], how='inner')

correlation_bio_5_17_enrol_5_17 = df_biometric_enrolment_combined['bio_age_5_17'].corr(df_biometric_enrolment_combined['age_5_17'])
correlation_bio_17_plus_enrol_18_plus = df_biometric_enrolment_combined['bio_age_17_'].corr(df_biometric_enrolment_combined['age_18_greater'])

print(f"Correlation between biometric updates (age 5-17) and enrollments (age 5-17): {correlation_bio_5_17_enrol_5_17:.2f}")
print(f"Correlation between biometric updates (age 17+) and enrollments (age 18+): {correlation_bio_17_plus_enrol_18_plus:.2f}")

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.scatterplot(x='bio_age_5_17', y='age_5_17', data=df_biometric_enrolment_combined)
plt.title('Biometric Updates vs. Enrollments (Age 5-17)')
plt.xlabel('Biometric Updates (Age 5-17)')
plt.ylabel('Enrollments (Age 5-17)')

plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.scatterplot(x='bio_age_17_', y='age_18_greater', data=df_biometric_enrolment_combined)
plt.title('Biometric Updates vs. Enrollments (Age 17+ and 18+)')
plt.xlabel('Biometric Updates (Age 17+)')
plt.ylabel('Enrollments (Age 18+)')

plt.tight_layout()
plt.show()
# Out:
# Correlation between biometric updates (age 5-17) and enrollments (age 5-17): 0.69
# Correlation between biometric updates (age 17+) and enrollments (age 18+): 0.29

# %% [markdown]
# # Enrolment

# %%
state_enrollments = df_enrolment.groupby('state')[['age_0_5', 'age_5_17', 'age_18_greater']].sum().reset_index()
state_enrollments['total_enrollments'] = state_enrollments['age_0_5'] + state_enrollments['age_5_17'] + state_enrollments['age_18_greater']
state_enrollments.head()
# Out:
#                          state  age_0_5  age_5_17  age_18_greater  \
# 0                       100000        0         1             217
# 1    Andaman & Nicobar Islands      109         5               0
# 2  Andaman and Nicobar Islands      370        27               0
# 3               Andhra Pradesh   112440     13746            1495
# 4            Arunachal Pradesh     1957      2236             151
#
#    total_enrollments
# 0                218
# 1                114
# 2                397
# 3             127681
# 4               4344

# %% [markdown]
# ## Identify Top 10 Enrollment States

# %%
top_10_enrollment_states = state_enrollments.sort_values(by='total_enrollments', ascending=False).head(10)
print("Top 10 states with the most enrollments:")
print(top_10_enrollment_states)
# Out:
# Top 10 states with the most enrollments:
#              state  age_0_5  age_5_17  age_18_greater  total_enrollments
# 45   Uttar Pradesh   521045    479682           17902            1018629
# 6            Bihar   262875    334802           11908             609585
# 27  Madhya Pradesh   367990    116381            9599             493970
# 51     West Bengal   275391     91396            8510             375297
# 28     Maharashtra   278814     82116            8209             369139
# 39       Rajasthan   229780    113123            5555             348458
# 16         Gujarat   193031     71182           16336             280549
# 5            Assam   141235     66085           22877             230197
# 23       Karnataka   179262     33863           10110             223235
# 41      Tamil Nadu   182313     37227            1249             220789

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data from the table
data = {
    'state': ['Uttar Pradesh', 'Bihar', 'Madhya Pradesh', 'West Bengal',
              'Maharashtra', 'Rajasthan', 'Gujarat', 'Assam',
              'Karnataka', 'Tamil Nadu'],
    'age_0_5': [521045, 262875, 367990, 275391, 278814, 229780, 193031, 141235, 179262, 182313],
    'age_5_17': [479682, 334802, 116381, 91396, 82116, 113123, 71182, 66085, 33863, 37227],
    'age_18_greater': [17902, 11908, 9599, 8510, 8209, 5555, 16336, 22877, 10110, 1249],
    'total_enrollments': [1018629, 609585, 493970, 375297, 369139, 348458, 280549, 230197, 223235, 220789]
}

df = pd.DataFrame(data)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Sort by total enrollments in descending order
df = df.sort_values('total_enrollments', ascending=True)

# Create horizontal bar chart
bars = ax.barh(df['state'], df['total_enrollments'], color='#3498db', edgecolor='black', linewidth=1.2)

# Add value labels on the bars
for i, (bar, value) in enumerate(zip(bars, df['total_enrollments'])):
    ax.text(value + 15000, bar.get_y() + bar.get_height()/2,
            f'{value:,}',
            va='center', ha='left', fontsize=11, fontweight='bold')

# Formatting
ax.set_xlabel('Total Enrollments', fontsize=13, fontweight='bold')
ax.set_ylabel('State', fontsize=13, fontweight='bold')
ax.set_title('Top 10 States with Most Enrollments', fontsize=16, fontweight='bold', pad=20)
ax.grid(axis='x', alpha=0.3, linestyle='--')

# Format x-axis with commas
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x):,}'))

# Adjust layout
plt.tight_layout()

# Save and show
plt.savefig('top_10_states_enrollments.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Chart saved as 'top_10_states_enrollments.png'")
print("\nTop 10 States Summary:")
print(df[['state', 'total_enrollments']].sort_values('total_enrollments', ascending=False).to_string(index=False))
# Out:
# ✓ Chart saved as 'top_10_states_enrollments.png'
#
# Top 10 States Summary:
#          state  total_enrollments
#  Uttar Pradesh            1018629
#          Bihar             609585
# Madhya Pradesh             493970
#    West Bengal             375297
#    Maharashtra             369139
#      Rajasthan             348458
#        Gujarat             280549
#          Assam             230197
#      Karnataka             223235
#     Tamil Nadu             220789

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Scatter 1: Age 0-5 vs Age 5-17
axes[0, 0].scatter(df['age_0_5'], df['age_5_17'], s=200, alpha=0.6,
                   c=df['total_enrollments'], cmap='viridis', edgecolors='black', linewidth=1.5)
for i, state in enumerate(df['state']):
    axes[0, 0].annotate(state, (df['age_0_5'].iloc[i], df['age_5_17'].iloc[i]),
                        fontsize=8, ha='right', va='bottom')
axes[0, 0].set_xlabel('Age 0-5 Enrollments', fontsize=11, fontweight='bold')
axes[0, 0].set_ylabel('Age 5-17 Enrollments', fontsize=11, fontweight='bold')
axes[0, 0].set_title('Age 0-5 vs Age 5-17 Enrollments', fontsize=13, fontweight='bold')
axes[0, 0].grid(alpha=0.3)

# Scatter 2: Age 0-5 vs Age 18+
axes[0, 1].scatter(df['age_0_5'], df['age_18_greater'], s=200, alpha=0.6,
                   c=df['total_enrollments'], cmap='plasma', edgecolors='black', linewidth=1.5)
for i, state in enumerate(df['state']):
    axes[0, 1].annotate(state, (df['age_0_5'].iloc[i], df['age_18_greater'].iloc[i]),
                        fontsize=8, ha='right', va='bottom')
axes[0, 1].set_xlabel('Age 0-5 Enrollments', fontsize=11, fontweight='bold')
axes[0, 1].set_ylabel('Age 18+ Enrollments', fontsize=11, fontweight='bold')
axes[0, 1].set_title('Age 0-5 vs Age 18+ Enrollments', fontsize=13, fontweight='bold')
axes[0, 1].grid(alpha=0.3)

# Scatter 3: Age 5-17 vs Age 18+
axes[1, 0].scatter(df['age_5_17'], df['age_18_greater'], s=200, alpha=0.6,
                   c=df['total_enrollments'], cmap='coolwarm', edgecolors='black', linewidth=1.5)
for i, state in enumerate(df['state']):
    axes[1, 0].annotate(state, (df['age_5_17'].iloc[i], df['age_18_greater'].iloc[i]),
                        fontsize=8, ha='right', va='bottom')
axes[1, 0].set_xlabel('Age 5-17 Enrollments', fontsize=11, fontweight='bold')
axes[1, 0].set_ylabel('Age 18+ Enrollments', fontsize=11, fontweight='bold')
axes[1, 0].set_title('Age 5-17 vs Age 18+ Enrollments', fontsize=13, fontweight='bold')
axes[1, 0].grid(alpha=0.3)

# Scatter 4: Total Enrollments vs State Index
state_idx = range(len(df))
axes[1, 1].scatter(state_idx, df['total_enrollments'], s=250, alpha=0.7,
                   c='steelblue', edgecolors='black', linewidth=1.5)
axes[1, 1].set_xticks(state_idx)
axes[1, 1].set_xticklabels(df['state'], rotation=45, ha='right', fontsize=9)
axes[1, 1].set_ylabel('Total Enrollments', fontsize=11, fontweight='bold')
axes[1, 1].set_title('Total Enrollments by State', fontsize=13, fontweight='bold')
axes[1, 1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('scatter_plots_enrollment.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Histogram 1: Total Enrollments
axes[0, 0].hist(df['total_enrollments'], bins=8, color='skyblue',
                edgecolor='black', alpha=0.7, linewidth=1.5)
axes[0, 0].axvline(df['total_enrollments'].mean(), color='red',
                   linestyle='--', linewidth=2, label=f"Mean: {df['total_enrollments'].mean():,.0f}")
axes[0, 0].axvline(df['total_enrollments'].median(), color='green',
                   linestyle='--', linewidth=2, label=f"Median: {df['total_enrollments'].median():,.0f}")
axes[0, 0].set_xlabel('Total Enrollments', fontsize=11, fontweight='bold')
axes[0, 0].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[0, 0].set_title('Distribution of Total Enrollments', fontsize=13, fontweight='bold')
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3)

# Histogram 2: Age 0-5
axes[0, 1].hist(df['age_0_5'], bins=8, color='coral',
                edgecolor='black', alpha=0.7, linewidth=1.5)
axes[0, 1].axvline(df['age_0_5'].mean(), color='red',
                   linestyle='--', linewidth=2, label=f"Mean: {df['age_0_5'].mean():,.0f}")
axes[0, 1].set_xlabel('Age 0-5 Enrollments', fontsize=11, fontweight='bold')
axes[0, 1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[0, 1].set_title('Distribution of Age 0-5 Enrollments', fontsize=13, fontweight='bold')
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3)

# Histogram 3: Age 5-17
axes[1, 0].hist(df['age_5_17'], bins=8, color='lightgreen',
                edgecolor='black', alpha=0.7, linewidth=1.5)
axes[1, 0].axvline(df['age_5_17'].mean(), color='red',
                   linestyle='--', linewidth=2, label=f"Mean: {df['age_5_17'].mean():,.0f}")
axes[1, 0].set_xlabel('Age 5-17 Enrollments', fontsize=11, fontweight='bold')
axes[1, 0].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[1, 0].set_title('Distribution of Age 5-17 Enrollments', fontsize=13, fontweight='bold')
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

# Histogram 4: Age 18+
axes[1, 1].hist(df['age_18_greater'], bins=8, color='plum',
                edgecolor='black', alpha=0.7, linewidth=1.5)
axes[1, 1].axvline(df['age_18_greater'].mean(), color='red',
                   linestyle='--', linewidth=2, label=f"Mean: {df['age_18_greater'].mean():,.0f}")
axes[1, 1].set_xlabel('Age 18+ Enrollments', fontsize=11, fontweight='bold')
axes[1, 1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[1, 1].set_title('Distribution of Age 18+ Enrollments', fontsize=13, fontweight='bold')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('histograms_enrollment.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))

x_pos = np.arange(len(df['state']))
width = 0.25

ax.bar(x_pos - width, df['age_0_5'], width, label='Age 0-5',
       color='#3498db', edgecolor='black', alpha=0.8)
ax.bar(x_pos, df['age_5_17'], width, label='Age 5-17',
       color='#e74c3c', edgecolor='black', alpha=0.8)
ax.bar(x_pos + width, df['age_18_greater'], width, label='Age 18+',
       color='#2ecc71', edgecolor='black', alpha=0.8)

ax.set_xticks(x_pos)
ax.set_xticklabels(df['state'], rotation=45, ha='right', fontsize=10)
ax.set_ylabel('Enrollments', fontsize=12, fontweight='bold')
ax.set_title('Age-wise Enrollments by State (Grouped)', fontsize=14, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('age_wise_grouped_bar.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))

ax.bar(df['state'], df['age_0_5'], label='Age 0-5',
       color='#3498db', edgecolor='black', alpha=0.8)
ax.bar(df['state'], df['age_5_17'], bottom=df['age_0_5'],
       label='Age 5-17', color='#e74c3c', edgecolor='black', alpha=0.8)
ax.bar(df['state'], df['age_18_greater'],
       bottom=df['age_0_5'] + df['age_5_17'],
       label='Age 18+', color='#2ecc71', edgecolor='black', alpha=0.8)

ax.set_xticklabels(df['state'], rotation=45, ha='right', fontsize=10)
ax.set_ylabel('Enrollments', fontsize=12, fontweight='bold')
ax.set_title('Age-wise Enrollments by State (Stacked)', fontsize=14, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('age_wise_stacked_bar.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))

age_0_5_pct = df['age_0_5'] / df['total_enrollments'] * 100
age_5_17_pct = df['age_5_17'] / df['total_enrollments'] * 100
age_18_pct = df['age_18_greater'] / df['total_enrollments'] * 100

ax.bar(df['state'], age_0_5_pct, label='Age 0-5',
       color='#3498db', edgecolor='black', alpha=0.8)
ax.bar(df['state'], age_5_17_pct, bottom=age_0_5_pct,
       label='Age 5-17', color='#e74c3c', edgecolor='black', alpha=0.8)
ax.bar(df['state'], age_18_pct,
       bottom=age_0_5_pct + age_5_17_pct,
       label='Age 18+', color='#2ecc71', edgecolor='black', alpha=0.8)

ax.set_xticklabels(df['state'], rotation=45, ha='right', fontsize=10)
ax.set_ylabel('Percentage (%)', fontsize=12, fontweight='bold')
ax.set_title('Age Distribution by State (% Stacked)', fontsize=14, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('age_wise_percentage_stacked.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

age_groups = ['Age 0-5', 'Age 5-17', 'Age 18+']
totals = [df['age_0_5'].sum(), df['age_5_17'].sum(), df['age_18_greater'].sum()]
colors_bar = ['#3498db', '#e74c3c', '#2ecc71']

bars = ax.bar(age_groups, totals, color=colors_bar, edgecolor='black', alpha=0.8, linewidth=1.5)

# Add value labels on bars
for i, v in enumerate(totals):
    ax.text(i, v + 50000, f'{v:,}', ha='center', fontsize=12, fontweight='bold')

ax.set_ylabel('Total Enrollments', fontsize=12, fontweight='bold')
ax.set_title('Total Enrollments by Age Group (All States)', fontsize=14, fontweight='bold')
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('total_by_age_group.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
print("\n" + "="*70)
print("SUMMARY STATISTICS")
print("="*70)

print("\n📊 Total Enrollments Statistics:")
print(f"  Mean: {df['total_enrollments'].mean():,.0f}")
print(f"  Median: {df['total_enrollments'].median():,.0f}")
print(f"  Std Dev: {df['total_enrollments'].std():,.0f}")
print(f"  Min: {df['total_enrollments'].min():,} ({df.loc[df['total_enrollments'].idxmin(), 'state']})")
print(f"  Max: {df['total_enrollments'].max():,} ({df.loc[df['total_enrollments'].idxmax(), 'state']})")

print("\n📊 Age Group Totals:")
print(f"  Age 0-5: {df['age_0_5'].sum():,} ({df['age_0_5'].sum()/df['total_enrollments'].sum()*100:.1f}%)")
print(f"  Age 5-17: {df['age_5_17'].sum():,} ({df['age_5_17'].sum()/df['total_enrollments'].sum()*100:.1f}%)")
print(f"  Age 18+: {df['age_18_greater'].sum():,} ({df['age_18_greater'].sum()/df['total_enrollments'].sum()*100:.1f}%)")

print("\n📊 State Rankings (Top 3):")
top3 = df.nlargest(3, 'total_enrollments')[['state', 'total_enrollments']]
for idx, row in top3.iterrows():
    print(f"  {row['state']}: {row['total_enrollments']:,}")
# Out:
# ...
# SUMMARY STATISTICS
# ...
#
# 📊 Total Enrollments Statistics:
#   Mean: 416,985
#   Median: 358,798
#   Std Dev: 245,686
#   Min: 220,789 (Tamil Nadu)
#   Max: 1,018,629 (Uttar Pradesh)
#
# 📊 Age Group Totals:
#   Age 0-5: 2,631,736 (63.1%)
#   Age 5-17: 1,425,857 (34.2%)
#   Age 18+: 112,255 (2.7%)
#
# 📊 State Rankings (Top 3):
#   Uttar Pradesh: 1,018,629
#   Bihar: 609,585
#   Madhya Pradesh: 493,970

# %% [markdown]
# #

# %%
df_combined_all = pd.merge(df_demographic, df_enrolment, on=['date', 'state', 'district', 'pincode'], how='outer')
df_combined_all = pd.merge(df_combined_all, df_biometric, on=['date', 'state', 'district', 'pincode'], how='outer')

# Save the combined DataFrame to a CSV file
df_combined_all.to_csv('combined_aadhar_data.csv', index=False)

print("Combined Aadhar data saved to 'combined_aadhar_data.csv'")
print(f"Shape of the combined DataFrame: {df_combined_all.shape}")
df_combined_all.head()
# Out:
# Combined Aadhar data saved to 'combined_aadhar_data.csv'
# Shape of the combined DataFrame: (2947681, 17)
#         date                        state  district  pincode  demo_age_5_17  \
# 0 2025-03-01    Andaman & Nicobar Islands  Andamans   744101            NaN
# 1 2025-03-01  Andaman and Nicobar Islands   Nicobar   744301           16.0
# 2 2025-03-01  Andaman and Nicobar Islands   Nicobar   744301           16.0
# 3 2025-03-01  Andaman and Nicobar Islands   Nicobar   744302            NaN
# 4 2025-03-01  Andaman and Nicobar Islands   Nicobar   744303            NaN
#
#    demo_age_17_  update_year  update_month  age_0_5  age_5_17  age_18_greater  \
# 0           NaN          NaN           NaN      NaN       NaN             NaN
# 1         180.0       2025.0           3.0      NaN       NaN             NaN
# 2         180.0       2025.0           3.0      NaN       NaN             NaN
# 3           NaN          NaN           NaN      NaN       NaN             NaN
# ...

# %%
from google.colab import files

# Replace 'combined_aadhar_data.csv' with the actual filename if it's different
files.download('combined_aadhar_data.csv')
